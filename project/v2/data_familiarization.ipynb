# %%
import pandas as pd

routes = pd.read_csv('gtfs_data/routes.csv')
stop_times = pd.read_csv('gtfs_data/stop_times.csv')
stops = pd.read_csv('gtfs_data/stops.csv')
transfers = pd.read_csv('gtfs_data/transfers.csv')
trips = pd.read_csv('gtfs_data/trips.csv')
translations = pd.read_csv('gtfs_data/translations.csv')

# %%
routes.head()
# Out:
#    route_id  agency_id route_short_name                    route_long_name  \
# 0         1  NMBS/SNCB              BUS    Lille Flandres (FR) -- Courtrai
# 1        10  NMBS/SNCB              BUS              Audenarde -- Zottegem
# 2       100  NMBS/SNCB              BUS        Charleroi-Central -- Couvin
# 3       101  NMBS/SNCB              BUS  Braine-le-Comte -- Saint-Ghislain
# 4       102  NMBS/SNCB              BUS            Mons -- Braine-le-Comte
#
#    route_desc  route_type  route_url  route_color  route_text_color
# 0         NaN         700        NaN          NaN               NaN
# 1         NaN         700        NaN          NaN               NaN
# 2         NaN         700        NaN          NaN               NaN
# 3         NaN         700        NaN          NaN               NaN
# 4         NaN         700        NaN          NaN               NaN

# %%
routes[routes["route_id"] == 546]
# Out:
#      route_id  agency_id route_short_name     route_long_name  route_desc  \
# 496       546  NMBS/SNCB               IC  Louvain -- Ostende         NaN
#
#      route_type  route_url  route_color  route_text_color
# 496         103        NaN          NaN               NaN

# %%
stop_times.head()
# Out:
#                                       trip_id arrival_time departure_time  \
# 0  87____:049::8728600:8889011:5:715:20241116     06:27:00       06:27:00
# 1  87____:049::8728600:8889011:5:715:20241116     06:40:00       06:40:00
# 2  87____:049::8728600:8889011:5:715:20241116     06:49:00       06:49:00
# 3  87____:049::8728600:8889011:5:715:20241116     07:01:00       07:01:00
# 4  87____:049::8728600:8889011:5:715:20241116     07:15:00       07:15:00
#
#    stop_id  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0  8728600              1            NaN            0              1
# 1  8728671              2            NaN            1              1
# 2  8728673              3            NaN            0              0
# 3  8728654              4            NaN            0              0
# 4  8889011              5            NaN            1              1
#
#    shape_dist_traveled
# 0                  NaN
# 1                  NaN
# 2                  NaN
# ...

# %%
stop_times[stop_times['trip_id'] == "80____:098::8015345:8065969:2:3226:20241212"]
# Out:
#                                             trip_id arrival_time  \
# 484327  80____:098::8015345:8065969:2:3226:20241212     20:55:00
# 484328  80____:098::8015345:8065969:2:3226:20241212     32:26:00
#
#        departure_time  stop_id  stop_sequence  stop_headsign  pickup_type  \
# 484327       21:10:00  8015345             43            NaN            0
# 484328       32:26:00  8065969             44            NaN            1
#
#         drop_off_type  shape_dist_traveled
# 484327              0                  NaN
# 484328              0                  NaN

# %%
stops.head()
# Out:
#    stop_id  stop_code              stop_name  stop_desc  stop_lat  stop_lon  \
# 0  8015190        NaN           Herzogenrath        NaN  50.87090  6.094400
# 1  8015199        NaN  Aix-la-Chapelle Ouest        NaN  50.78078  6.070550
# 2  8015345        NaN        Aachen Hbf (DE)        NaN  50.76776  6.091390
# 3  8015458        NaN          Köln Hbf (DE)        NaN  50.94308  6.958970
# 4  8061676        NaN   Frankfurt Flugh (DE)        NaN  50.13083  8.663611
#
#    zone_id  stop_url  location_type parent_station platform_code  \
# 0      NaN       NaN              0            NaN           NaN
# 1      NaN       NaN              0            NaN           NaN
# 2      NaN       NaN              0            NaN           NaN
# 3      NaN       NaN              0            NaN           NaN
# 4      NaN       NaN              0            NaN           NaN
#
#    stop_timezone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
transfers.head()
# Out:
#    from_stop_id  to_stop_id  transfer_type  min_transfer_time  from_route_id  \
# 0       8811429     8814472              2                300            NaN
# 1       8814472     8811429              2                300            NaN
# 2       8821147     8821154              2                300            NaN
# 3       8821154     8821147              2                300            NaN
# 4       8863115     8863354              2                420            NaN
#
#    to_route_id  from_trip_id  to_trip_id
# 0          NaN           NaN         NaN
# 1          NaN           NaN         NaN
# 2          NaN           NaN         NaN
# 3          NaN           NaN         NaN
# 4          NaN           NaN         NaN

# %%
trips.head()
# Out:
#    route_id  service_id                                      trip_id  \
# 0         1           1   87____:049::8728600:8889011:5:715:20241116
# 1         1           1   88____:049::8889011:8896008:3:748:20241116
# 2         2           2  88____:049::8892007:8896008:6:2516:20241121
# 3         3           3   88____:049::8895208:8895802:9:649:20241201
# 4         4           4   88____:049::8892908:8892601:2:925:20241126
#
#   trip_headsign  trip_short_name  direction_id  block_id  shape_id  trip_type
# 0      Courtrai            11000           NaN         1       NaN          1
# 1      Courtrai            11000           NaN         1       NaN          1
# 2      Courtrai            11000           NaN         2       NaN          1
# 3   Denderleeuw            11000           NaN         3       NaN          1
# 4     Audenarde            11000           NaN         4       NaN          1

# %%
translations.head()
# Out:
#   table_name field_name language   translation  record_id  record_sub_id  \
# 0      stops  stop_name       nl  Ingelmunster        NaN            NaN
# 1      stops  stop_name       de  Ingelmunster        NaN            NaN
# 2      stops  stop_name       en  Ingelmunster        NaN            NaN
# 3      stops  stop_name       nl        Izegem        NaN            NaN
# 4      stops  stop_name       de        Izegem        NaN            NaN
#
#     field_value
# 0  Ingelmunster
# 1  Ingelmunster
# 2  Ingelmunster
# 3        Izegem
# 4        Izegem
