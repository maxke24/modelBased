# %%
import re

def extract_integers_from_string(s):
    # Use regex to find all sequences of digits in the string
    integers = re.findall(r'\d+', str(s))
    # Convert the found sequences to integers
    return [int(num) for num in integers]

# Example usage
string = "50a and 2b, some_text 123"
integers = extract_integers_from_string(string)
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import unicodedata

def normalize_string(s):
    # Normalize the string to NFKD form and encode it to ASCII bytes, ignoring errors
    normalized = unicodedata.normalize('NFKD', s).encode('ascii', 'ignore').decode('ascii')
    return normalized

# Example usage
string = "è, é, ê, and other accents"
normalized_string = normalize_string(string)
print(normalized_string)  # Output: e, e, e, and other accents
# Out:
# e, e, e, and other accents

# %%
import os
import csv
import networkx as nx
import pandas as pd

# Function to create graph from a single CSV file
def create_graph_from_csv(file_path, G):
    data = pd.read_csv(file_path)
    data['sp-tekst-r'] = data['sp-tekst-r'].str.strip().str.lower()
    for i in range(len(data)):
        node = data.loc[i, 'sp-tekst-r']
        line_number = data.loc[i, 'line_number']
        if G.has_node(node):
            if 'line_numbers' in G.nodes[node]:
                if line_number not in G.nodes[node]['line_numbers']:
                    G.nodes[node]['line_numbers'].append(line_number)
            else:
                G.nodes[node]['line_numbers'] = [line_number]
        else:
            G.add_node(node, pos=(i, data.loc[i, 'sp-km']), line_numbers=[line_number])
    for i in range(len(data) - 1):
        node1 = data.loc[i, 'sp-tekst-r']
        node2 = data.loc[i + 1, 'sp-tekst-r']
        dist = data.loc[i + 1, 'sp-km'] - data.loc[i, 'sp-km']
        if dist > 0:
            G.add_edge(node1, node2, weight=dist)
    return G

# Initialize the combined graph
G_combined = nx.Graph()

# Directory containing CSV files
csv_directory = 'csv_filtered'

# Read each CSV file and update the combined graph
for file_name in os.listdir(csv_directory):
    if file_name.endswith('.csv'):
        file_path = os.path.join(csv_directory, file_name)
        try:
            G_combined = create_graph_from_csv(file_path, G_combined)
        except:
            G_combined = G_combined

# Export the graph to ASP format
def export_to_asp(graph, file_path):
    with open(file_path, 'w') as file:
        for node, data in graph.nodes(data=True):
            line_numbers = data.get('line_numbers', [])
            for line in line_numbers:
                file.write(f"node({normalize_string(node).replace('-', '_').replace(' ', '_')}, {int(extract_integers_from_string(line)[0])}).\n")
                #print(f"node({normalize_string(node).replace('-', '_').replace(' ', '_')}, {int(extract_integers_from_string(line)[0])}).\n")
        for node1, node2, data in graph.edges(data=True):
            weight = data.get('weight', 1)
            file.write(f"edge({normalize_string(node1).replace('-', '_').replace(' ', '_')}, {normalize_string(node2).replace('-', '_').replace(' ', '_')}, {int(weight)}).\n")

# Export the combined graph to a .lp file
export_to_asp(G_combined, 'graph_all_filtered.lp')

print("Graph exported to graph.lp.")
# Out:
# node(brussel_noord, 0).
#
# node(brussel_noord, 25).
#
# node(brussel_noord, 27).
#
# node(brussel_noord, 36).
#
# node(brussel_noord, 36).
#
# node(brussel_noord, 50).
#
# node(brussel_congres, 0).
#
# node(brussel_centraal, 0).
#
# node(brussel_kapellekerk, 0).
#
# node(brussel_zuid, 0).
#
# node(brussel_zuid, 124).
#
# node(brussel_zuid, 28).
#
# node(brussel_zuid, 50).
#
# node(brussel_zuid, 96).
#
# node(manage, 116).
#
# node(manage, 117).
#
# node(la_louviere_centrum, 116).
#
# node('s_gravenbrakel, 117).
#
# node('s_gravenbrakel, 96).
#
# node(ecaussinnes, 117).
#
# node(gouy_lez_pieton, 117).
#
# node(luttre, 117).
#
# node(luttre, 124).
#
# node(bergen, 118).
#
# node(bergen, 96).
#
# node(scheldewindeke, 122).
#
# node(balegem_dorp, 122).
#
# node(zottegem, 122).
#
# node(zottegem, 89).
#
# node(lierde, 122).
#
# node(geraardsbergen, 122).
#
# node(vorst_oost, 124).
#
# node(ukkel_stalle, 124).
#
# node(ukkel_kalevoet, 124).
#
# node(linkebeek, 124).
#
# node(sint_genesius_rode, 124).
#
# node(de_hoek, 124).
#
# node(waterloo, 124).
#
# node(eigenbrakel, 124).
#
# node(lillois, 124).
#
# node(nijvel, 124).
#
# node(obaix_buzet, 124).
#
# node(courcelles_motte, 124).
#
# node(marchienne_au_pont, 124).
#
# node(charleroi_centraal, 124).
#
# node(charleroi_centraal, 130).
#
# node(charleroi_centraal, 130).
#
# node(luik_guillemins, 125).
#
# node(luik_guillemins, 36).
#
# node(luik_guillemins, 37).
#
# node(pont_de_seraing, 125).
#
# node(jemeppe_sur_meuse, 125).
#
# node(flemalle_haute, 125).
#
# node(flemalle_haute, 125).
#
# node(engis, 125).
#
# node(amay, 125).
#
# node(ampsin, 125).
#
# node(statte, 125).
#
# node(andenne, 125).
#
# node(namen, 125).
#
# node(namen, 130).
#
# node(namen, 161).
#
# node(namen, 162).
#
# node(seraing, 125).
#
# node(kontich_lint, 13).
#
# node(kontich_lint, 25).
#
# node(kontich_lint, 27).
#
# node(lier, 13).
#
# node(floreffe, 130).
#
# node(franiere, 130).
#
# node(moustier, 130).
#
# node(jemeppe_sur_sambre, 130).
#
# node(jemeppe_sur_sambre, 144).
#
# node(auvelais, 130).
#
# node(tamines, 130).
#
# node(farciennes, 130).
#
# node(chatelet, 130).
#
# node(thuin, 130).
#
# node(couvin, 134).
#
# node(leuven, 139).
#
# node(leuven, 35).
#
# node(leuven, 36).
#
# node(leuven, 36).
#
# node(leuven, 53).
#
# node(heverlee, 139).
#
# node(sint_joris_weert, 139).
#
# node(pecrot, 139).
#
# node(gastuche, 139).
#
# node(basse_wavre, 139).
#
# node(waver, 139).
#
# node(limal, 139).
#
# node(ottignies, 139).
#
# node(ottignies, 140).
#
# node(ottignies, 161).
#
# node(ceroux_mousty, 140).
#
# node(court_saint_etienne, 140).
#
# node(la_roche, 140).
#
# node(villers_la_ville, 140).
#
# node(tilly, 140).
#
# node(ligny, 140).
#
# node(fleurus, 140).
#
# node(gembloers, 144).
#
# node(gembloers, 161).
#
# node(berlaar, 16).
#
# node(melkouwen, 16).
#
# node(heist_op_den_berg, 16).
#
# node(booischot, 16).
#
# node(begijnendijk, 16).
#
# node(schaarbeek, 161).
#
# node(schaarbeek, 25).
#
# node(schaarbeek, 26).
#
# node(schaarbeek, 27).
#
# node(schaarbeek, 28).
#
# node(schaarbeek, 36).
#
# node(schaarbeek, 36).
#
# node(brussel_schuman, 161).
#
# node(brussel_luxemburg, 161).
#
# node(etterbeek, 161).
#
# node(watermaal, 161).
#
# node(bosvoorde, 161).
#
# node(groenendaal, 161).
#
# node(hoeilaart, 161).
#
# node(terhulpen, 161).
#
# node(genval, 161).
#
# node(rixensart, 161).
#
# node(profondsart, 161).
#
# node(louvain_la_neuve, 161).
#
# node(louvain_la_neuve, 161).
#
# node(mont_saint_guibert, 161).
#
# node(blanmont, 161).
#
# node(chastre, 161).
#
# node(lonzee, 161).
#
# node(saint_denis_bovesse, 161).
#
# node(rhisnes, 161).
#
# node(jambes_oost, 162).
#
# node(naninne, 162).
#
# node(sart_bernard, 162).
#
# node(courriere, 162).
#
# node(assesse, 162).
#
# node(natoye, 162).
#
# node(ciney, 162).
#
# node(marloie, 162).
#
# node(marloie, 43).
#
# node(rochefort_jemelle, 162).
#
# node(libramont, 162).
#
# node(libramont, 165).
#
# node(marbehan, 162).
#
# node(aarlen, 162).
#
# node(bertrix, 165).
#
# node(bertrix, 166).
#
# node(virton, 165).
#
# node(athus, 165).
#
# node(beauraing, 166).
#
# node(mol, 19).
#
# node(lommel, 19).
#
# node(overpelt, 19).
#
# node(neerpelt, 19).
#
# node(landen, 21).
#
# node(landen, 36).
#
# node(sint_truiden, 21).
#
# node(alken, 21).
#
# node(hasselt, 21).
#
# node(hasselt, 35).
#
# node(genk, 21).
#
# node(tongeren, 24).
#
# node(vilvoorde, 25).
#
# node(vilvoorde, 27).
#
# node(eppegem, 25).
#
# node(eppegem, 27).
#
# node(weerde, 25).
#
# node(weerde, 27).
#
# node(mechelen, 25).
#
# node(mechelen, 27).
#
# node(mechelen, 53).
#
# node(mechelen_nekkerspoel, 25).
#
# node(mechelen_nekkerspoel, 27).
#
# node(duffel, 25).
#
# node(duffel, 27).
#
# node(hove, 25).
#
# node(hove, 27).
#
# node(mortsel_oude_god, 25).
#
# node(antwerpen_berchem, 25).
#
# node(antwerpen_berchem, 27).
#
# node(antwerpen_berchem, 27).
#
# node(antwerpen_centraal, 25).
#
# node(antwerpen_centraal, 27).
#
# node(bordet, 26).
#
# node(evere, 26).
#
# node(meiser, 26).
#
# node(merode, 26).
#
# node(delta, 26).
#
# node(boondaal, 26).
#
# node(sint_job, 26).
#
# node(moensberg, 26).
#
# node(beersel, 26).
#
# node(huizingen, 26).
#
# node(halle, 26).
#
# node(halle, 94).
#
# node(halle, 96).
#
# node(mortsel_liersesteenweg, 27).
#
# node(mortsel, 27).
#
# node(brussel_west, 28).
#
# node(wezemaal, 35).
#
# node(aarschot, 35).
#
# node(testelt, 35).
#
# node(zichem, 35).
#
# node(diest, 35).
#
# node(schulen, 35).
#
# node(haren_zuid, 36).
#
# node(haren_zuid, 36).
#
# node(diegem, 36).
#
# node(diegem, 36).
#
# node(zaventem, 36).
#
# node(zaventem, 36).
#
# node(zaventem, 36).
#
# node(nossegem, 36).
#
# node(nossegem, 36).
#
# node(kortenberg, 36).
#
# node(kortenberg, 36).
#
# node(erps_kwerps, 36).
#
# node(erps_kwerps, 36).
#
# node(veltem, 36).
#
# node(veltem, 36).
#
# node(herent, 36).
#
# node(herent, 36).
#
# node(vertrijk, 36).
#
# node(tienen, 36).
#
# node(ezemaal, 36).
#
# node(borgworm, 36).
#
# node(ans, 36).
#
# node(angleur, 37).
#
# node(angleur, 43).
#
# node(nessonvaux, 37).
#
# node(pepinster, 37).
#
# node(welkenraedt, 37).
#
# node(rivage, 42).
#
# node(rivage, 43).
#
# node(aywaille, 42).
#
# node(trois_ponts, 42).
#
# node(vielsalm, 42).
#
# node(gouvy, 42).
#
# node(tilff, 43).
#
# node(esneux, 43).
#
# node(poulseur, 43).
#
# node(comblain_la_tour, 43).
#
# node(hamoir, 43).
#
# node(bomal, 43).
#
# node(barvaux, 43).
#
# node(melreux_hotton, 43).
#
# node(marche_en_famenne, 43).
#
# node(bockstael, 50).
#
# node(jette, 50).
#
# node(jette, 60).
#
# node(sint_agatha_berchem, 50).
#
# node(groot_bijgaarden, 50).
#
# node(dilbeek, 50).
#
# node(sint_martens_bodegem, 50).
#
# node(ternat, 50).
#
# node(essene_lombeek, 50).
#
# node(liedekerke, 50).
#
# node(denderleeuw, 50).
#
# node(denderleeuw, 89).
#
# node(erembodegem, 50).
#
# node(aalst, 50).
#
# node(lede, 50).
#
# node(serskamp, 50).
#
# node(schellebelle, 50).
#
# node(schellebelle, 53).
#
# node(wetteren, 50).
#
# node(melle, 50).
#
# node(merelbeke, 50).
#
# node(gent_sint_pieters, 50).
#
# node(gent_sint_pieters, 50).
#
# node(welle, 50).
#
# node(welle, 89).
#
# node(drongen, 50).
#
# node(landegem, 50).
#
# node(hansbeke, 50).
#
# node(aalter, 50).
#
# node(maria_aalter, 50).
#
# node(beernem, 50).
#
# node(oostende, 50).
#
# node(heist, 51).
#
# node(knokke, 51).
#
# node(wichelen, 53).
#
# node(oudegem, 53).
#
# node(dendermonde, 53).
#
# node(dendermonde, 60).
#
# node(buggenhout, 53).
#
# node(malderen, 53).
#
# node(londerzeel, 53).
#
# node(kapelle_op_den_bos, 53).
#
# node(muizen, 53).
#
# node(boortmeerbeek, 53).
#
# node(haacht, 53).
#
# node(wespelaar_tildonk, 53).
#
# node(wijgmaal, 53).
#
# node(zwijndrecht, 59).
#
# node(melsele, 59).
#
# node(sint_niklaas, 59).
#
# node(belsele, 59).
#
# node(sinaai, 59).
#
# node(lokeren, 59).
#
# node(beervelde, 59).
#
# node(gent_dampoort, 59).
#
# node(zellik, 60).
#
# node(asse, 60).
#
# node(mollem, 60).
#
# node(merchtem, 60).
#
# node(opwijk, 60).
#
# node(heizijde, 60).
#
# node(lebbeke, 60).
#
# node(sint_gillis, 60).
#
# node(zedelgem, 66).
#
# node(torhout, 66).
#
# node(lichtervelde, 66).
#
# node(roeselare, 66).
#
# node(izegem, 66).
#
# node(ingelmunster, 66).
#
# node(kortrijk, 66).
#
# node(moeskroen, 75).
#
# node(herzeeuw, 75).
#
# node(froyennes, 75).
#
# node(froyennes, 94).
#
# node(saint_ghislain, 78).
#
# node(blaton, 78).
#
# node(peruwelz, 78).
#
# node(antoing, 78).
#
# node(doornik, 78).
#
# node(doornik, 94).
#
# node(haaltert, 89).
#
# node(ede, 89).
#
# node(burst, 89).
#
# node(terhagen, 89).
#
# node(herzele, 89).
#
# node(munkzwalm, 89).
#
# node(anzegem, 89).
#
# node(vichte, 89).
#
# node(edingen, 94).
#
# node(opzullik, 94).
#
# node(aat, 94).
#
# node(leuze, 94).
#
# node(vorst_zuid, 96).
#
# node(ruisbroek, 96).
#
# node(lot, 96).
#
# node(buizingen, 96).
#
# node(lembeek, 96).
#
# node(tubeke, 96).
#
# node(hennuyeres, 96).
#
# node(zinnik, 96).
#
# node(jurbeke, 96).
#
# node(quevy, 96).
#
# Graph exported to graph.lp.
