# %%
import pandas as pd

df_stop_times = pd.read_csv("gtfs_data/stop_times.csv")
df_stops = pd.read_csv("gtfs_data/stops.csv")
df_translations = pd.read_csv("gtfs_data/translations.csv")

df_stop_times.head()
# Out:
#                                       trip_id arrival_time departure_time  \
# 0  87____:049::8728600:8889011:5:715:20241116     06:27:00       06:27:00
# 1  87____:049::8728600:8889011:5:715:20241116     06:40:00       06:40:00
# 2  87____:049::8728600:8889011:5:715:20241116     06:49:00       06:49:00
# 3  87____:049::8728600:8889011:5:715:20241116     07:01:00       07:01:00
# 4  87____:049::8728600:8889011:5:715:20241116     07:15:00       07:15:00
#
#    stop_id  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0  8728600              1            NaN            0              1
# 1  8728671              2            NaN            1              1
# 2  8728673              3            NaN            0              0
# 3  8728654              4            NaN            0              0
# 4  8889011              5            NaN            1              1
#
#    shape_dist_traveled
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df_translations.head(10)
# Out:
#   table_name     field_name language          translation  record_id  \
# 0      stops      stop_name       nl         Ingelmunster        NaN
# 1      stops      stop_name       de         Ingelmunster        NaN
# 2      stops      stop_name       en         Ingelmunster        NaN
# 3      stops      stop_name       nl               Izegem        NaN
# 4      stops      stop_name       de               Izegem        NaN
# 5      stops      stop_name       en               Izegem        NaN
# 6      stops      stop_name       nl            Roeselare        NaN
# 7      trips  trip_headsign       nl            Roeselare        NaN
# 8      stops      stop_name       de  Roeselare / Roulers        NaN
# 9      trips  trip_headsign       de  Roeselare / Roulers        NaN
#
#    record_sub_id   field_value
# 0            NaN  Ingelmunster
# 1            NaN  Ingelmunster
# 2            NaN  Ingelmunster
# 3            NaN        Izegem
# 4            NaN        Izegem
# 5            NaN        Izegem
# 6            NaN       Roulers
# 7            NaN       Roulers
# 8            NaN       Roulers
# 9            NaN       Roulers

# %%
df_stops.head()
# Out:
#    stop_id  stop_code              stop_name  stop_desc  stop_lat  stop_lon  \
# 0  8015190        NaN           Herzogenrath        NaN  50.87090  6.094400
# 1  8015199        NaN  Aix-la-Chapelle Ouest        NaN  50.78078  6.070550
# 2  8015345        NaN        Aachen Hbf (DE)        NaN  50.76776  6.091390
# 3  8015458        NaN          Köln Hbf (DE)        NaN  50.94308  6.958970
# 4  8061676        NaN   Frankfurt Flugh (DE)        NaN  50.13083  8.663611
#
#    zone_id  stop_url  location_type parent_station platform_code  \
# 0      NaN       NaN              0            NaN           NaN
# 1      NaN       NaN              0            NaN           NaN
# 2      NaN       NaN              0            NaN           NaN
# 3      NaN       NaN              0            NaN           NaN
# 4      NaN       NaN              0            NaN           NaN
#
#    stop_timezone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
import pandas as pd

# Filter the translations DataFrame to include only Dutch translations
df_translations_nl = df_translations[df_translations['language'] == 'nl']

# Merge the DataFrames on the French stop names
df_translated = df_stops.merge(df_translations_nl, left_on='stop_name', right_on='field_value', how='left')

# Replace the French stop names with Dutch translations
df_translated['stop_name'] = df_translated['translation']
df_translated = df_translated[['stop_id', 'stop_name']]

# %%
df_translations_nl.head()
# Out:
#    table_name     field_name language   translation  record_id  record_sub_id  \
# 0       stops      stop_name       nl  Ingelmunster        NaN            NaN
# 3       stops      stop_name       nl        Izegem        NaN            NaN
# 6       stops      stop_name       nl     Roeselare        NaN            NaN
# 7       trips  trip_headsign       nl     Roeselare        NaN            NaN
# 12      stops      stop_name       nl     Poperinge        NaN            NaN
#
#      field_value
# 0   Ingelmunster
# 3         Izegem
# 6        Roulers
# 7        Roulers
# 12     Poperinge

# %%
df_stop_times["stop_id"] = df_stop_times["stop_id"].astype(str)

df_translated["stop_id"] = df_translated["stop_id"].astype(str)

# %%
df_merged = pd.merge(df_stop_times, df_translated, on='stop_id')

# %%
df_merged.head()
# Out:
#                                       trip_id arrival_time departure_time  \
# 0  87____:049::8728600:8889011:5:715:20241116     06:27:00       06:27:00
# 1  87____:049::8728600:8889011:5:715:20241116     06:40:00       06:40:00
# 2  87____:049::8728600:8889011:5:715:20241116     06:49:00       06:49:00
# 3  87____:049::8728600:8889011:5:715:20241116     07:01:00       07:01:00
# 4  87____:049::8728600:8889011:5:715:20241116     07:15:00       07:15:00
#
#    stop_id  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0  8728600              1            NaN            0              1
# 1  8728671              2            NaN            1              1
# 2  8728673              3            NaN            0              0
# 3  8728654              4            NaN            0              0
# 4  8889011              5            NaN            1              1
#
#    shape_dist_traveled           stop_name
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN  Mouscron-Frontière

# %%
df_cleaned = df_merged[["trip_id", "departure_time", "stop_id", "stop_sequence", "stop_name"]]

# %%
# Split the departure_time column into hours and minutes
df_cleaned['hours'] = df_cleaned['departure_time'].str.split(':', expand=True)[0]
df_cleaned['minutes'] = df_cleaned['departure_time'].str.split(':', expand=True)[1]

# Convert hours and minutes to integers to remove leading zeros
df_cleaned['hours'] = df_cleaned['hours'].astype(int)
df_cleaned['minutes'] = df_cleaned['minutes'].astype(int)
# Out:
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_43724\699540803.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['hours'] = df_cleaned['departure_time'].str.split(':', expand=True)[0]
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_43724\699540803.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['minutes'] = df_cleaned['departure_time'].str.split(':', expand=True)[1]
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_43724\699540803.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['hours'] = df_cleaned['hours'].astype(int)
# C:\Users\Jelle\AppData\Local\Temp\ipykernel_43724\699540803.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['minutes'] = df_cleaned['minutes'].astype(int)

# %%
df_cleaned.head()
# Out:
#                                       trip_id departure_time  stop_id  \
# 0  87____:049::8728600:8889011:5:715:20241116       06:27:00  8728600
# 1  87____:049::8728600:8889011:5:715:20241116       06:40:00  8728671
# 2  87____:049::8728600:8889011:5:715:20241116       06:49:00  8728673
# 3  87____:049::8728600:8889011:5:715:20241116       07:01:00  8728654
# 4  87____:049::8728600:8889011:5:715:20241116       07:15:00  8889011
#
#    stop_sequence           stop_name  hours  minutes
# 0              1                 NaN      6       27
# 1              2                 NaN      6       40
# 2              3                 NaN      6       49
# 3              4                 NaN      7        1
# 4              5  Mouscron-Frontière      7       15

# %%
mask = df_cleaned['stop_name'].isin(['Brussel-Noord'])
df_cleaned[mask].head()
# Out:
#                                            trip_id departure_time  stop_id  \
# 25296  88____:049::8814001:8811601:17:747:20241117       06:01:00  8812005
# 25297  88____:049::8814001:8811601:17:747:20241117       06:01:00  8812005
# 55168  88____:046::8821006:8814001:20:654:20241130       06:46:00  8812005
# 55169  88____:046::8821006:8814001:20:654:20241130       06:46:00  8812005
# 55245  88____:046::8814001:8821006:20:724:20250413       06:18:00  8812005
#
#        stop_sequence      stop_name  hours  minutes
# 25296              5  Brussel-Noord      6        1
# 25297              5  Brussel-Noord      6        1
# 55168             16  Brussel-Noord      6       46
# 55169             16  Brussel-Noord      6       46
# 55245              5  Brussel-Noord      6       18

# %%
# Step 1: Read the graph.lp file and extract the list of nodes
nodes = []
with open('graph_all_filtered.lp', 'r') as file:
    for line in file:
        if line.startswith('node('):
            node = line.split('(')[1].split(',')[0]
            nodes.append(node)
print(nodes)
# Out:
# ['brussel_noord', 'brussel_noord', 'brussel_noord', 'brussel_noord', 'brussel_noord', 'brussel_noord', 'brussel_congres', 'brussel_centraal', 'brussel_zuid', 'brussel_zuid', 'brussel_zuid', 'brussel_zuid', 'brussel_zuid', 'la_louviere_centrum', "'s_gravenbrakel", "'s_gravenbrakel", 'ecaussinnes', 'luttre', 'luttre', 'bergen', 'bergen', 'zottegem', 'zottegem', 'geraardsbergen', 'vorst_oost', 'ukkel_kalevoet', 'linkebeek', 'sint_genesius_rode', 'waterloo', 'eigenbrakel', 'lillois', 'nijvel', 'marchienne_au_pont', 'charleroi_centraal', 'charleroi_centraal', 'charleroi_centraal', 'luik_guillemins', 'luik_guillemins', 'luik_guillemins', 'flemalle_haute', 'flemalle_haute', 'hoei', 'statte', 'andenne', 'namen', 'namen', 'namen', 'namen', 'seraing', 'kontich_lint', 'kontich_lint', 'kontich_lint', 'lier', 'auvelais', 'tamines', 'chatelet', 'leuven', 'leuven', 'leuven', 'leuven', 'leuven', 'heverlee', 'waver', 'ottignies', 'ottignies', 'ottignies', 'court_saint_etienne', 'gembloers', 'gembloers', 'heist_op_den_berg', 'schaarbeek', 'schaarbeek', 'schaarbeek', 'schaarbeek', 'schaarbeek', 'schaarbeek', 'schaarbeek', 'brussel_schuman', 'brussel_luxemburg', 'etterbeek', 'etterbeek', 'bosvoorde', 'groenendaal', 'terhulpen', 'genval', 'rixensart', 'louvain_la_neuve', 'louvain_la_neuve', 'ciney', 'marloie', 'marloie', 'rochefort_jemelle', 'libramont', 'libramont', 'marbehan', 'aarlen', 'athus', 'mol', 'landen', 'landen', 'sint_truiden', 'alken', 'hasselt', 'hasselt', 'genk', 'tongeren', 'vilvoorde', 'vilvoorde', 'eppegem', 'eppegem', 'weerde', 'weerde', 'mechelen', 'mechelen', 'mechelen', 'mechelen_nekkerspoel', 'mechelen_nekkerspoel', 'sint_katelijne_waver', 'sint_katelijne_waver', 'duffel', 'duffel', 'hove', 'hove', 'mortsel_oude_god', 'antwerpen_berchem', 'antwerpen_berchem', 'antwerpen_berchem', 'antwerpen_centraal', 'antwerpen_centraal', 'bordet', 'meiser', 'boondaal', 'sint_job', 'halle', 'halle', 'halle', 'mortsel', 'wezemaal', 'aarschot', 'diest', 'haren_zuid', 'haren_zuid', 'diegem', 'diegem', 'zaventem', 'zaventem', 'zaventem', 'nossegem', 'nossegem', 'kortenberg', 'kortenberg', 'herent', 'herent', 'vertrijk', 'tienen', 'borgworm', 'ans', 'brussels_airport_zaventem', 'angleur', 'angleur', 'pepinster', 'welkenraedt', 'barvaux', 'bockstael', 'jette', 'jette', 'sint_agatha_berchem', 'groot_bijgaarden', 'dilbeek', 'sint_martens_bodegem', 'ternat', 'liedekerke', 'denderleeuw', 'denderleeuw', 'erembodegem', 'aalst', 'lede', 'schellebelle', 'schellebelle', 'wetteren', 'melle', 'merelbeke', 'gent_sint_pieters', 'gent_sint_pieters', 'landegem', 'aalter', 'beernem', 'brugge', 'brugge', 'oostende', 'knokke', 'dendermonde', 'dendermonde', 'buggenhout', 'londerzeel', 'kapelle_op_den_bos', 'boortmeerbeek', 'haacht', 'wijgmaal', 'antwerpen_zuid', 'sint_niklaas', 'lokeren', 'beervelde', 'gent_dampoort', 'zellik', 'asse', 'merchtem', 'opwijk', 'heizijde', 'lebbeke', 'zedelgem', 'torhout', 'lichtervelde', 'roeselare', 'izegem', 'ingelmunster', 'kortrijk', 'moeskroen', 'herzeeuw', 'froyennes', 'froyennes', 'saint_ghislain', 'blaton', 'peruwelz', 'doornik', 'doornik', 'haaltert', 'ede', 'burst', 'oudenaarde', 'edingen', 'opzullik', 'aat', 'leuze', 'vorst_zuid', 'ruisbroek', 'lot', 'buizingen', 'lembeek', 'tubeke', 'hennuyeres', 'zinnik', 'jurbeke']

# %%
df_cleaned['stop_name'] = df_cleaned['stop_name'].str.lower().str.replace('-', '_')

df_filtered = df_cleaned[df_cleaned['stop_name'].isin(nodes)]
df_filtered.drop_duplicates()
# Converteer de DataFrame naar ASP-regels
asp_rules = []
for index, row in df_filtered.iterrows():
    if not 'nan' in str(row['stop_name']):
        if not f"departure_time({row['stop_id']}, '{row['hours']}', '{row['minutes']}')." in asp_rules:
            asp_rules.append(f"departure_time({row['stop_id']}, '{row['hours']}', '{row['minutes']}').")
        if not f"stop_id({row['stop_id']}, {row['stop_sequence']})." in asp_rules:
            asp_rules.append(f"stop_id({row['stop_id']}, {row['stop_sequence']}).")
        if not f"stop_sequence({row['stop_id']}, {row['stop_sequence']})." in asp_rules:    
            asp_rules.append(f"stop_sequence({row['stop_id']}, {row['stop_sequence']}).")
        if not f"stop_name({row['stop_id']}, '{row['stop_name']}')." in asp_rules:
            asp_rules.append(f"stop_name({row['stop_id']}, '{row['stop_name']}').")


asp_program = "\n".join(asp_rules)

# Print of sla het ASP-programma op
with open('schedule.lp', 'w') as file:
    file.write(asp_program)

# %%
df_cleaned
# Out:
#                                             trip_id departure_time  stop_id  \
# 0        87____:049::8728600:8889011:5:715:20241116       06:27:00  8728600
# 1        87____:049::8728600:8889011:5:715:20241116       06:40:00  8728671
# 2        87____:049::8728600:8889011:5:715:20241116       06:49:00  8728673
# 3        87____:049::8728600:8889011:5:715:20241116       07:01:00  8728654
# 4        87____:049::8728600:8889011:5:715:20241116       07:15:00  8889011
# ...                                             ...            ...      ...
# 902665  88____:046::8865003:8864345:6:2130:20251213       21:21:00  8864311
# 902666  88____:046::8865003:8864345:6:2130:20251213       21:25:00  8864006
# 902667  88____:046::8865003:8864345:6:2130:20251213       21:25:00  8864006
# 902668  88____:046::8865003:8864345:6:2130:20251213       21:30:00  8864345
# 902669  88____:046::8865003:8864345:6:2130:20251213       21:30:00  8864345
#
#         stop_sequence           stop_name  hours  minutes
# 0                   1                 NaN      6       27
# 1                   2                 NaN      6       40
# 2                   3                 NaN      6       49
# 3                   4                 NaN      7        1
# 4                   5  mouscron_frontière      7       15
# ...               ...                 ...    ...      ...
# 902665              4           forrières     21       21
# 902666              5   rochefort_jemelle     21       25
# 902667              5   rochefort_jemelle     21       25
# 902668              6             marloie     21       30
# 902669              6             marloie     21       30
#
# [902670 rows x 7 columns]

# %%
df_filtered
# Out:
#                                             trip_id departure_time  stop_id  \
# 6        88____:049::8889011:8896008:3:748:20241116       07:18:00  8885704
# 7        88____:049::8889011:8896008:3:748:20241116       07:18:00  8885704
# 8        88____:049::8889011:8896008:3:748:20241116       07:48:00  8896008
# 9        88____:049::8889011:8896008:3:748:20241116       07:48:00  8896008
# 10      88____:049::8892007:8896008:6:2516:20241121       23:43:00  8892007
# ...                                             ...            ...      ...
# 902662  88____:046::8865003:8864345:6:2130:20251213       20:56:00  8865003
# 902666  88____:046::8865003:8864345:6:2130:20251213       21:25:00  8864006
# 902667  88____:046::8865003:8864345:6:2130:20251213       21:25:00  8864006
# 902668  88____:046::8865003:8864345:6:2130:20251213       21:30:00  8864345
# 902669  88____:046::8865003:8864345:6:2130:20251213       21:30:00  8864345
#
#         stop_sequence          stop_name  hours  minutes
# 6                   6          moeskroen      7       18
# 7                   6          moeskroen      7       18
# 8                   7           kortrijk      7       48
# 9                   7           kortrijk      7       48
# 10                  1  gent_sint_pieters     23       43
# ...               ...                ...    ...      ...
# 902662              1          libramont     20       56
# 902666              5  rochefort_jemelle     21       25
# 902667              5  rochefort_jemelle     21       25
# 902668              6            marloie     21       30
# 902669              6            marloie     21       30
#
# [510004 rows x 7 columns]
